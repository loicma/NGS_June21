# %% [markdown]
# ## Inspiré analyse Juan

# %%
import sys
sys.version
# Out:
# '3.7.7 (default, May  6 2020, 11:45:54) [MSC v.1916 64 bit (AMD64)]'

# %%
import pandas as pd
import math
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import py3Dmol as py3D
import bokeh as bk
import pandas_bokeh as pd_bk
pd_bk.output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %%
py3D.__version__
# Out:
# '1.8.0'

# %%
p = py3D.view(query='mmtf:1ycr')
p.setStyle({'cartoon': {'color':'spectrum'}})
p
# Out:
# <div id="3dmolviewer_1658136003001227"  style="position: relative; width: 640px; height: 480px">
#         <p id="3dmolwarning_1658136003001227" style="background-color:#ffcccc;color:black">You appear to be running in JupyterLab (or JavaScript failed to load for some other reason).  You need to install the 3dmol extension: <br>
#         <tt>jupyter labextension install jupyterlab_3dmol</tt></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#       resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://3dmol.org/build/3Dmol.js');
# }
#
# var viewer_1658136003001227 = null;
# ...

# %%
view = py3D.view(query='pdb:1ycr')
chA = {'chain':'A'}
chB = {'chain':'B'}
view.setStyle(chA,{'cartoon': {'color':'spectrum'}})
view.addSurface(py3D.VDW,{'opacity':0.7,'color':'white'}, chA)
view.setStyle(chB,{'stick':{}})
view.show()
# Out:
# <div id="3dmolviewer_16581418770368118"  style="position: relative; width: 640px; height: 480px">
#         <p id="3dmolwarning_16581418770368118" style="background-color:#ffcccc;color:black">You appear to be running in JupyterLab (or JavaScript failed to load for some other reason).  You need to install the 3dmol extension: <br>
#         <tt>jupyter labextension install jupyterlab_3dmol</tt></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#       resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://3dmol.org/build/3Dmol.js');
# }
#
# ...

# %%
plt = py3D.view(query='pdb:5m2i')
chB = {'chain':'B'}
plt.setStyle(chB,{'cartoon': {'color':'spectrum'}})
plt.addSurface(py3D.VDW,{'opacity':0.6,'color':'white'}, chB)
chG = {'chain':'G'}
plt.setStyle(chG,{'cartoon': {'color':'spectrum'}})
plt.addSurface(py3D.VDW,{'opacity':0.7,'color':'white'}, chG)

plt.show()
# Out:
# <div id="3dmolviewer_16581360472116778"  style="position: relative; width: 640px; height: 480px">
#         <p id="3dmolwarning_16581360472116778" style="background-color:#ffcccc;color:black">You appear to be running in JupyterLab (or JavaScript failed to load for some other reason).  You need to install the 3dmol extension: <br>
#         <tt>jupyter labextension install jupyterlab_3dmol</tt></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#       resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://3dmol.org/build/3Dmol.js');
# }
#
# ...
